# %%
# %pip install ultralytics import YOLO
# %pip install roboflow
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement import (from versions: none)
# ERROR: No matching distribution found for import
# ...

# %% [markdown]
# # get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="qwqBfkEyGvzTYt0DXGFG")
project = rf.workspace("tom-inglin-lpnv1").project("p1-jz5ap")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# 'c:\\Users\\Jerm\\Documents\\classwork\\Software_Engineering_Capstone\\training\\P1-3'

# %%
import shutil
import torch
print(torch.cuda.is_available())  # Should return True if GPU is available
print(torch.cuda.device_count())  # Should show the number of GPUs available
# Out:
# False
# 0

# %% [markdown]
# # Training

# %%
# !yolo task=detect mode=train model = yolov8n.pt data = {dataset.location}/data.yaml epochs = 100 imgsz = 640
# Out:
# New https://pypi.org/project/ultralytics/8.3.78 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.74 🚀 Python-3.12.9 torch-2.6.0+cpu CPU (AMD Ryzen 7 5700X3D 8-Core Processor)
# ...
